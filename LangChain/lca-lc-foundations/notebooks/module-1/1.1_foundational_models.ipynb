# %%
# %pip install -U langchain langchain-community langchain-core langchain-groq

# %%
# %pip install -U langgraph
# Out:
# Requirement already satisfied: langgraph in c:\users\mr. john ota\appdata\local\programs\python\python312\lib\site-packages (1.0.6)
# Requirement already satisfied: langchain-core>=0.1 in c:\users\mr. john ota\appdata\local\programs\python\python312\lib\site-packages (from langgraph) (1.2.7)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\mr. john ota\appdata\local\programs\python\python312\lib\site-packages (from langgraph) (2.1.2)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\mr. john ota\appdata\local\programs\python\python312\lib\site-packages (from langgraph) (1.0.6)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\mr. john ota\appdata\local\programs\python\python312\lib\site-packages (from langgraph) (0.3.3)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\mr. john ota\appdata\local\programs\python\python312\lib\site-packages (from langgraph) (2.12.5)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\mr. john ota\appdata\local\programs\python\python312\lib\site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in c:\users\mr. john ota\appdata\local\programs\python\python312\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\mr. john ota\appdata\local\programs\python\python312\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\mr. john ota\appdata\local\programs\python\python312\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11.5)
# Requirement already satisfied: anyio in c:\users\mr. john ota\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (4.12.1)
# Requirement already satisfied: certifi in c:\users\mr. john ota\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\mr. john ota\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.0.9)
# Requirement already satisfied: idna in c:\users\mr. john ota\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\mr. john ota\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\mr. john ota\appdata\local\programs\python\python312\lib\site-packages (from langchain-core>=0.1->langgraph) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\mr. john ota\appdata\local\programs\python\python312\lib\site-packages (from langchain-core>=0.1->langgraph) (0.6.4)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\mr. john ota\appdata\local\programs\python\python312\lib\site-packages (from langchain-core>=0.1->langgraph) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\mr. john ota\appdata\local\programs\python\python312\lib\site-packages (from langchain-core>=0.1->langgraph) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\mr. john ota\appdata\local\programs\python\python312\lib\site-packages (from langchain-core>=0.1->langgraph) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\mr. john ota\appdata\local\programs\python\python312\lib\site-packages (from langchain-core>=0.1->langgraph) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\mr. john ota\appdata\local\programs\python\python312\lib\site-packages (from langchain-core>=0.1->langgraph) (0.13.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\mr. john ota\appdata\local\programs\python\python312\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.1->langgraph) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\mr. john ota\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\mr. john ota\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\mr. john ota\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\mr. john ota\appdata\local\programs\python\python312\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\mr. john ota\appdata\local\programs\python\python312\lib\site-packages (from pydantic>=2.7.4->langgraph) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\mr. john ota\appdata\local\programs\python\python312\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\mr. john ota\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mr. john ota\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.6.3)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~iohttp (c:\Users\Mr. John Ota\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~iohttp (c:\Users\Mr. John Ota\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~iohttp (c:\Users\Mr. John Ota\AppData\Local\Programs\Python\Python312\Lib\site-packages)

# %%
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model="llama-3.3-70b-versatile", 
    model_provider="groq",
    api_key=os.getenv("OPENAI_API_KEY")
)

# %%
response = model.invoke("What's the capital of the Moon?")

response

# %%
print(response.content)

# %%
from pprint import pprint

pprint(response.response_metadata)

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="llama-3.3-70b-versatile", 
    model_provider="groq",
    api_key=os.getenv("OPENAI_API_KEY"),
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon is a natural satellite of Earth, and it does not have a capital city. The Moon has no permanent human settlements or established governments, so there is no need for a capital city. It's a pretty cool place to explore, though, with its rugged terrain and fascinating geological features! Would you like to know more about the Moon?

# %%
from pprint import pprint
pprint(response.response_metadata)

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# That's a fun question! The Moon doesn't have a capital city like Earth does. It's a celestial body, not a country or a populated planet.
#
# However, if we were to imagine a hypothetical capital, it would likely be a place of great significance to humans, perhaps where the first permanent base might be established. Some popular fictional locations or ideas for a "capital" on the Moon include:
#
# *   **Tranquility Base:** The landing site of Apollo 11, the first human landing. It's historically significant.
# *   **A large, established lunar colony:** If humans were to colonize the Moon, the central hub of that colony would likely function as a de facto capital.
#
# But in reality, there's no such thing as a capital of the Moon.

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import AgentExecutor, create_tool_calling_agent
from langchain_core.prompts import ChatPromptTemplate

# 1. Setup the Prompt
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant."),
    ("placeholder", "{chat_history}"),
    ("human", "{input}"),
    ("placeholder", "{agent_scratchpad}"),
])

# 2. Define Tools (Even an empty list if just testing, but usually functions)
tools = [] 

# 3. Construct the Tool Calling Agent
agent = create_tool_calling_agent(model, tools, prompt)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from langchain.agents import AgentExecutor, create_tool_calling_agent
#       2 from langchain_core.prompts import ChatPromptTemplate
#       4 # 1. Setup the Prompt
#
# File c:\Users\Mr. John Ota\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain\agents\__init__.py:3
#       1 """Entrypoint to building [Agents](https://docs.langchain.com/oss/python/langchain/agents) with LangChain."""  # noqa: E501
# ----> 3 from langchain.agents.factory import create_agent
#       4 from langchain.agents.middleware.types import AgentState
#       6 __all__ = [
#       7     "AgentState",
#       8     "create_agent",
#       9 ]
#
# File c:\Users\Mr. John Ota\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain\agents\factory.py:22
#      20 from langgraph.constants import END, START
#      21 from langgraph.graph.state import StateGraph
# ---> 22 from langgraph.prebuilt.tool_node import ToolCallWithContext, ToolNode
#      23 from langgraph.types import Command, Send
#      24 from typing_extensions import NotRequired, Required, TypedDict
#
# ModuleNotFoundError: No module named 'langgraph.prebuilt.tool_node'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)

# %%
print(response['messages'][-1].content)

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
